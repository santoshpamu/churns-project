# %% [markdown]
# # importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # step:1

# %%
df=pd.read_csv(r"C:\Users\home\Downloads\churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['TotalCharges'].isnull().sum()
df['TotalCharges'].describe()
# Out:
# count     7043
# unique    6531
# top
# freq        11
# Name: TotalCharges, dtype: object

# %%
df['TotalCharges']=df['TotalCharges'].apply(lambda x:0 if x == ' ' else x)
df['TotalCharges'].median()
# Out:
# 1394.55

# %%
df['TotalCharges']=df['TotalCharges'].apply(lambda x:float(x))
df['TotalCharges'].describe()
# Out:
# count    7043.000000
# mean     2279.734304
# std      2266.794470
# min         0.000000
# 25%       398.550000
# 50%      1394.550000
# 75%      3786.600000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
df['TotalCharges'].fillna(1394.55,inplace = True)
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df.drop(columns = 'customerID',inplace=True,axis=1)
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# # Step:2

# %% [markdown]
# # Target Variable

# %%
# Identify the Target Variable and Splitting the Data into Train and Test
y = df['Churn']
X=df[['gender','SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges']]

# %%
#our target variable is discrete(nominal),so we are using CLASIIFICATION TASK
df['SeniorCitizen'].value_counts() #OHE
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df['gender'].value_counts() #OHE
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['Partner'].value_counts() #OHE
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
df['Dependents'].value_counts() #OHE
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
df['tenure'].value_counts() #OHE
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df['PhoneService'].value_counts() #OHE
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
df['MultipleLines'].value_counts() #OHE
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
df['InternetService'].value_counts() #OHE
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['OnlineBackup'].value_counts() #OHE
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
df['DeviceProtection'].value_counts() #OHE
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
df['TechSupport'].value_counts() #OHE
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
df['StreamingMovies'].value_counts() #OHE
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
df['PaperlessBilling'].value_counts() #OHE
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
df['PaymentMethod'].value_counts() #OHE
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
df['MonthlyCharges'].value_counts() #OHE
# Out:
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: MonthlyCharges, Length: 1585, dtype: int64

# %%
df['TotalCharges'].value_counts() #OHE
# Out:
# 0.00       11
# 20.20      11
# 19.75       9
# 20.05       8
# 19.90       8
#            ..
# 6849.40     1
# 692.35      1
# 130.15      1
# 3211.90     1
# 6844.50     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
df['Churn'].value_counts() #OHE
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Contract'].value_counts() #LE
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %% [markdown]
# # Step:3

# %%
# split into train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=100)

X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6630    Male              1      No         No      16          Yes
# 7013  Female              0      No         No      40          Yes
# 2224    Male              1     Yes         No      17          Yes
# 6580  Female              0     Yes        Yes      49          Yes
# 1501    Male              0      No         No      13          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 6630            No     Fiber optic                   No                   No
# 7013           Yes     Fiber optic                   No                  Yes
# 2224            No     Fiber optic                   No                  Yes
# 6580            No             DSL                   No                  Yes
# 1501            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (5282, 19) (5282,)
# (1761, 19) (1761,)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %% [markdown]
# # DATA PREPARATION ON TRAIN DATA

# %% [markdown]
# # Separating categorical numerical columns:

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6630    Male              1      No         No      16          Yes
# 7013  Female              0      No         No      40          Yes
# 2224    Male              1     Yes         No      17          Yes
# 6580  Female              0     Yes        Yes      49          Yes
# 1501    Male              0      No         No      13          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 6630            No     Fiber optic                   No                   No
# 7013           Yes     Fiber optic                   No                  Yes
# 2224            No     Fiber optic                   No                  Yes
# 6580            No             DSL                   No                  Yes
# 1501            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
X_train.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %% [markdown]
# ##### categorical columns

# %%
X_train_cat = X_train.select_dtypes(include=['object'])
X_train_cat

X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 6630    Male      No         No          Yes            No     Fiber optic
# 7013  Female      No         No          Yes           Yes     Fiber optic
# 2224    Male     Yes         No          Yes            No     Fiber optic
# 6580  Female     Yes        Yes          Yes            No             DSL
# 1501    Male      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 6630                   No                   No                   No
# 7013                   No                  Yes                  Yes
# 2224                   No                  Yes                   No
# 6580                   No                  Yes                  Yes
# 1501  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
X_train_cat.shape
# Out:
# (5282, 15)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %% [markdown]
# #### numerical columns

# %%
X_train_num = X_train.select_dtypes(include=['int64','float64'])

X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65

# %%
X_train_num.shape
# Out:
# (5282, 4)

# %% [markdown]
# # Applying OneHotEncoding on Categorical Columns:

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names(X_train_cat.columns), 
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6630          1.0          0.0             0.0               1.0
# 7013          0.0          0.0             0.0               1.0
# 2224          1.0          1.0             0.0               1.0
# 6580          0.0          1.0             1.0               1.0
# 1501          1.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 6630                             0.0                0.0
# 7013                             0.0                1.0
# 2224                             0.0                0.0
# 6580                             0.0                0.0
# 1501                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 6630                          1.0                 0.0
# 7013                          1.0                 0.0
# 2224                          1.0                 0.0
# ...

# %%
X_train_cat_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5282 entries, 6630 to 5640
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender_Male                            5282 non-null   float64
#  1   Partner_Yes                            5282 non-null   float64
#  2   Dependents_Yes                         5282 non-null   float64
#  3   PhoneService_Yes                       5282 non-null   float64
#  4   MultipleLines_No phone service         5282 non-null   float64
#  5   MultipleLines_Yes                      5282 non-null   float64
#  6   InternetService_Fiber optic            5282 non-null   float64
#  7   InternetService_No                     5282 non-null   float64
#  8   OnlineSecurity_No internet service     5282 non-null   float64
#  9   OnlineSecurity_Yes                     5282 non-null   float64
# ...

# %%
X_train_cat_ohe.shape
# Out:
# (5282, 26)

# %% [markdown]
# # Encoding Ordinal Columns

# %%
X_train_cat_le = pd.DataFrame(index=X_train_cat.index)#for CONTRACT COLUMN IT HAS AN ORDER

X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [6630, 7013, 2224, 6580, 1501]

# %%
X_train_cat.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
Contract_encoder = {'Month-to-month' : 1, 'One year' : 2, 'Two year' : 3}

X_train_cat_le['Contract'] = X_train_cat['Contract'].apply(lambda x :Contract_encoder[x])

X_train_cat_le
# Out:
#       Contract
# 6630         1
# 7013         1
# 2224         1
# 6580         2
# 1501         3
# ...        ...
# 79           2
# 3927         1
# 5955         3
# 6936         1
# 5640         1
#
# [5282 rows x 1 columns]

# %%
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65

# %% [markdown]
# # Scaling the numerical Fetures in the train data

# %%
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65

# %%
X_train_num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65
# ...             ...     ...             ...           ...
# 79                0      45           25.90       1216.60
# 3927              0       3           20.55         51.15
# 5955              0      72           68.40       4855.35
# 6936              0       5           80.15        385.00
# 5640              0       1           79.60         79.60
#
# [5282 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 6630       2.289869 -0.669552        0.471732     -0.470089
# 7013      -0.436706  0.305416        0.957819      0.650454
# 2224       2.289869 -0.628928        0.395418     -0.463401
# 6580      -0.436706  0.671028        0.446847      0.680387
# 1501      -0.436706 -0.791422       -1.479251     -0.900356

# %% [markdown]
# # concatinating Encoded categorical & Numerical columns

# %%
X_train_transformed = pd.concat([X_train_num_rescaled,X_train_cat_ohe,X_train_cat_le], axis=1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 6630       2.289869 -0.669552        0.471732     -0.470089          1.0
# 7013      -0.436706  0.305416        0.957819      0.650454          0.0
# 2224       2.289869 -0.628928        0.395418     -0.463401          1.0
# 6580      -0.436706  0.671028        0.446847      0.680387          0.0
# 1501      -0.436706 -0.791422       -1.479251     -0.900356          1.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6630          0.0             0.0               1.0
# 7013          0.0             0.0               1.0
# 2224          1.0             0.0               1.0
# 6580          1.0             1.0               1.0
# 1501          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  StreamingTV_Yes  \
# 6630                             0.0                0.0  ...              0.0
# ...

# %%
X_train_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5282 entries, 6630 to 5640
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   SeniorCitizen                          5282 non-null   float64
#  1   tenure                                 5282 non-null   float64
#  2   MonthlyCharges                         5282 non-null   float64
#  3   TotalCharges                           5282 non-null   float64
#  4   gender_Male                            5282 non-null   float64
#  5   Partner_Yes                            5282 non-null   float64
#  6   Dependents_Yes                         5282 non-null   float64
#  7   PhoneService_Yes                       5282 non-null   float64
#  8   MultipleLines_No phone service         5282 non-null   float64
#  9   MultipleLines_Yes                      5282 non-null   float64
# ...

# %% [markdown]
# # Step:5

# %% [markdown]
# # data preparation on test data

# %%
X_test.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4880    Male              0     Yes         No      50          Yes
# 1541    Male              0      No         No      72          Yes
# 1289    Male              0      No         No      63          Yes
# 5745  Female              0     Yes        Yes      61          Yes
# 4873  Female              0      No         No       7          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 4880            No              No  No internet service  No internet service
# 1541            No              No  No internet service  No internet service
# 1289           Yes             DSL                  Yes                  Yes
# 5745           Yes              No  No internet service  No internet service
# 4873            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
X_test.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
X_test.TotalCharges.value_counts()
# Out:
# 74.70      4
# 45.30      3
# 470.60     2
# 44.00      2
# 92.75      2
#           ..
# 1233.15    1
# 713.75     1
# 1206.05    1
# 223.90     1
# 4408.45    1
# Name: TotalCharges, Length: 1721, dtype: int64

# %%
#CATEGORICAL COLUMNS
X_test_cat = X_test.select_dtypes(include=['object'])
X_test_cat

X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 4880    Male     Yes         No          Yes            No              No
# 1541    Male      No         No          Yes            No              No
# 1289    Male      No         No          Yes           Yes             DSL
# 5745  Female     Yes        Yes          Yes           Yes              No
# 4873  Female      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 4880  No internet service  No internet service  No internet service
# 1541  No internet service  No internet service  No internet service
# 1289                  Yes                  Yes                  Yes
# 5745  No internet service  No internet service  No internet service
# 4873  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
#NUMERICAL COLUMNS
X_test_num = X_test.select_dtypes(include=['int64','float64'])

X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 4880              0      50           20.55       1067.65
# 1541              0      72           19.85       1434.10
# 1289              0      63           68.80       4111.35
# 5745              0      61           24.20       1445.20
# 4873              0       7           19.30        144.95

# %% [markdown]
# # Applying OneotEncoding On Categorical columns

# %%
X_test_cat_ohe = pd.DataFrame(encoder.transform(X_test_cat), 
                               columns=encoder.get_feature_names(X_test_cat.columns), 
                               index = X_test_cat.index)

X_test_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4880          1.0          1.0             0.0               1.0
# 1541          1.0          0.0             0.0               1.0
# 1289          1.0          0.0             0.0               1.0
# 5745          0.0          1.0             1.0               1.0
# 4873          0.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 4880                             0.0                0.0
# 1541                             0.0                0.0
# 1289                             0.0                1.0
# 5745                             0.0                1.0
# 4873                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 4880                          0.0                 1.0
# 1541                          0.0                 1.0
# 1289                          0.0                 0.0
# ...

# %%
X_test_cat_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1761 entries, 4880 to 3368
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender_Male                            1761 non-null   float64
#  1   Partner_Yes                            1761 non-null   float64
#  2   Dependents_Yes                         1761 non-null   float64
#  3   PhoneService_Yes                       1761 non-null   float64
#  4   MultipleLines_No phone service         1761 non-null   float64
#  5   MultipleLines_Yes                      1761 non-null   float64
#  6   InternetService_Fiber optic            1761 non-null   float64
#  7   InternetService_No                     1761 non-null   float64
#  8   OnlineSecurity_No internet service     1761 non-null   float64
#  9   OnlineSecurity_Yes                     1761 non-null   float64
# ...

# %% [markdown]
# # Scaling Numerical Features

# %%
X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 4880              0      50           20.55       1067.65
# 1541              0      72           19.85       1434.10
# 1289              0      63           68.80       4111.35
# 5745              0      61           24.20       1445.20
# 4873              0       7           19.30        144.95

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num), 
                                    columns = X_test_num.columns, 
                                    index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 4880      -0.436706  0.711652       -1.459343     -0.536576
# 1541      -0.436706  1.605372       -1.482569     -0.374796
# 1289      -0.436706  1.239759        0.141591      0.807158
# 5745      -0.436706  1.158512       -1.338236     -0.369895
# 4873      -0.436706 -1.035164       -1.500818     -0.943930

# %% [markdown]
# # Encoding Ordinal columns:

# %%
X_test_cat_le = pd.DataFrame(index=X_test_cat.index)#for CONTRACT COLUMN IT HAS AN ORDER

X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [4880, 1541, 1289, 5745, 4873]

# %%
X_test_cat.Contract.unique()
# Out:
# array(['Two year', 'One year', 'Month-to-month'], dtype=object)

# %%
Contract_encoder = {'Month-to-month' : 1, 'One year' : 2, 'Two year' : 3}

X_test_cat_le['Contract'] = X_test_cat['Contract'].apply(lambda x :Contract_encoder[x])

X_test_cat_le
# Out:
#       Contract
# 4880         3
# 1541         3
# 1289         2
# 5745         3
# 4873         1
# ...        ...
# 3287         2
# 571          3
# 6368         1
# 25           1
# 3368         2
#
# [1761 rows x 1 columns]

# %%
X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 4880              0      50           20.55       1067.65
# 1541              0      72           19.85       1434.10
# 1289              0      63           68.80       4111.35
# 5745              0      61           24.20       1445.20
# 4873              0       7           19.30        144.95

# %% [markdown]
# # Concatinating Encoded categorical &Numerical columns

# %%
X_test_transformed = pd.concat([X_test_num_rescaled,X_test_cat_ohe,X_test_cat_le], axis=1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 4880      -0.436706  0.711652       -1.459343     -0.536576          1.0
# 1541      -0.436706  1.605372       -1.482569     -0.374796          1.0
# 1289      -0.436706  1.239759        0.141591      0.807158          1.0
# 5745      -0.436706  1.158512       -1.338236     -0.369895          0.0
# 4873      -0.436706 -1.035164       -1.500818     -0.943930          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4880          1.0             0.0               1.0
# 1541          0.0             0.0               1.0
# 1289          0.0             0.0               1.0
# 5745          1.0             1.0               1.0
# 4873          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  StreamingTV_Yes  \
# 4880                             0.0                0.0  ...              0.0
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# # Step:6

# %% [markdown]
# # Using Required Algorithms Here

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
regressor= LogisticRegression()
regressor.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = regressor.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7842135150482681

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbour = KNeighborsClassifier()
neighbour.fit(X_train_transformed, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = neighbour.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual' : y_test,'Predicted' :y_test_pred })
temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7558205565019875

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X_train_transformed,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = tree.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual' : y_test,'Predicted' :y_test_pred })
temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.6956274843838728

# %% [markdown]
# # Ensembles Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train_transformed,y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred = rfc.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual' : y_test,'Predicted' :y_test_pred })
temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7791027825099376

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(X_train_transformed,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_test_pred = gbc.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual' : y_test,'Predicted' :y_test_pred })
temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7842135150482681

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_transformed,y_train)
# Out:
# GaussianNB()

# %%
y_test_pred = gnb.predict(X_test_transformed)
temp_df = pd.DataFrame({'Actual' : y_test,'Predicted' :y_test_pred })
temp_df.head()
# Out:
#      Actual Predicted
# 4880     No        No
# 1541     No        No
# 1289     No        No
# 5745     No        No
# 4873     No        No

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.6519023282226007

# %% [markdown]
# # Step:8

# %%
Logistic Regression : 0.7842135150482681
KNN CLASSIFIER      : 0.7558205565019875
Decision Tree       : 0.6973310618966496
Random Forest       : 0.7762634866553095
Gradient Boosting   : 0.7830777967064169
Naive Bayes         : 0.6519023282226007

# %%
#Logistic/random/Gradient are giving the highest accuracy
